# %%
nombre = "Francisco"
nombre
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-2b3156147be0> in <module>
# ----> 1 nombre = Francisco
#       2 nombre
#       3
#
# NameError: name 'Francisco' is not defined

# %%
nombre = "Francisco"

# %%
nombre
# Out:
# 'Francisco'
